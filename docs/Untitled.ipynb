# %%
import random
import geopatra
import geopandas
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
cities = geopandas.read_file(geopandas.datasets.get_path('naturalearth_cities'))
cities['value'] = [int(random.randint(10, 1000)) for i in range(len(cities))]

# %%
world.plot(column= 'gdp_md_est', cmap='YlGnBu', legend=True)

# %% [markdown]
# ## Folium Plots
# ```
# Kind = "default" (default)
#        "circle"
#        "markercluster"
#        "heatmap"
# ```

# %%
world.head(1)
# Out:
#    pop_est continent  name iso_a3  gdp_md_est  \
# 0   920938   Oceania  Fiji    FJI      8374.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...

# %%
world.folium.plot(zoom=1, tooltip=["continent"])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
world.folium.plot(
          color_by= 'gdp_md_est',
          color= 'YlGn',
          tooltip = ["continent"],
          style = {'weight': 1},
          zoom= 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4f4883167f70> in <module>
#       4           tooltip = ["continent"],
#       5           style = {'weight': 1},
# ----> 6           zoom= 1)
#
# ~/dev/geopatra/geopatra/map.py in plot(self, kind, **kwargs)
#      20     def plot(self, kind=None, **kwargs):
#      21         """Plot geodataframe wih folium."""
# ---> 22         return FoliumMap(kind)(self._gdf, **kwargs)
#      23
#      24
#
# ~/dev/geopatra/geopatra/folium/main.py in __call__(self, gdf, **kwargs)
#      12         kind = self.kind
#      13         if (kind == "default") or (kind is None):
# ---> 14             m = folium.geojson(gdf, **kwargs)
#      15         elif kind == "circle":
#      16             m = folium.circle(gdf, **kwargs)
#
# ~/dev/geopatra/geopatra/folium/geojson.py in geojson(gdf, color_by, name, width, height, location, color, tooltip, index_col, legend, zoom, tiles, attr, style)
#      69             object_col = index_col
#      70         layer_dict = gpd_copy.set_index([object_col])[color_by]
# ---> 71         color_dict = {key: colormap(layer_dict[key]) for key in layer_dict.keys()}
#      72         folium.GeoJson(
#      73             gpd_copy.to_json(),
#
# ~/dev/geopatra/geopatra/folium/geojson.py in <dictcomp>(.0)
#      69             object_col = index_col
#      70         layer_dict = gpd_copy.set_index([object_col])[color_by]
# ---> 71         color_dict = {key: colormap(layer_dict[key]) for key in layer_dict.keys()}
#      72         folium.GeoJson(
#      73             gpd_copy.to_json(),
#
# TypeError: 'str' object is not callable

# %%
cities.folium.plot(kind = "heatmap", zoom=1)
